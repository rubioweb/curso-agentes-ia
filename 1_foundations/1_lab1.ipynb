# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
groq_api_key = os.getenv('GROQ_API_KEY')

if groq_api_key:
    print(f"OpenAI API Key exists and begins {groq_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins gsk_7yGe

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# Ahora creamos una instancia de la clase Openai
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI(
    api_key=os.getenv('GROQ_API_KEY'),
    base_url="https://api.groq.com/openai/v1"
)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Cuanto es 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable
# parámetro model por uno que Groq tenga en sus servidores de forma gratuita.

response = openai.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# La respuesta a 2+2 es 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A finite, non-repeating sequence of 7 numbers is created by recursively taking the first prime number that isn't the sum of two distinct, previously used prime numbers; then the process repeats for the resulting sequence of prime numbers. What is the 27th number in this sequence?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To find the 27th number in this sequence, we need to generate the sequence by following the given process.
#
# 1. The first prime number is 2.
# 2. The next prime number is 3. (It is not the sum of 2.)
#    But, we're going to make an assumption. We must use the first two prime numbers before generating a new prime number. Hence,
#    the third prime number should not be the sum of the first two prime numbers, 2 and 3 (which equals 5). The next prime number is 5, but not for the reason we might initially assume. We are given in the task that the first prime numbers must be 2 & 3 before the 4th prime number, 5. Then, we must exclude 5 from the options because 5 could be the 4th prime number in this sequence, given the initial prime numbers. The next prime number that fits is actually 5 + 5 (not 5 +3), but not actually because we are summing two distinct prime numbers. This process will need an example to make more sense of it.
#    However, following this initial process of generating prime numbers with the initial values 2 & 3. Then, 5, 7 & 11 are also considered, as follows:
#    (2,3,5,7,11), (2, 3, 5, 7).
#
# Now we can exclude some of the prime numbers for being the sum of two distinct prime numbers from our list of prime numbers to determine our final list as we go on with the prime numbers.
# Now we know the first number in this sequence is 2 and then 3; hence 2 and 3 aren't added to the set of prime numbers we are not allowed to generate.
#
# Now moving on.
#
# For the 3rd number in the sequence: the number should not be (2+3, 5) or (3+5, 8) or (2+5,7) or (5+3, 8) or (5+2, 7) or (3+2, 5). So 7 is our only option to exclude 5 and continue to 2+5 which is a sum we mustn't create.
#
# The next prime is (11), because 7 + 2, (which equals 9) is also not allowed, because we can't generate sums like (9,11).
#
# So we get (2, 3, 5, 7, 11).
#
# Now we have a new sequence. We start here.
#
# 3. 13 - Not generated (3 + 10 not considered) because 7 was added, however we know we should be including another prime in this sequence: this is actually 13 because:
#       5+2= 7. Therefore, we also add these two other primes: 9 (2+7) & 11 + 3 = 14 which isn't prime. The reason for adding 13 is that it is prime, yet it has been excluded with previous logic of the other prime, which is (2+7). We will keep this number for further analysis. 5+7 is also a distinct prime & we will keep it out because 2 + 5 = 7.
# The primes not generated by the process include (11= 2 +5 - no), (13 = 2 + 3, is 5), no prime is generated by (5+3) = (8 + a prime or the prime that we know we must generate is actually 13), as is (5 + 7) = (12 + an undefined prime), as is (2+3), and (2+7 as we also see here, as are the primes 7 +3 and (3+2), (3+5), as are primes 7 + 3) (9+ a non prime 11 +2= 13) (7+2= no, and we also know that) and 3 + 5 = (3+10) (2 + 11).
#
# However with a new set of values, we get to start the sequence anew.
#
# Therefore, the second prime isn't 5, but actually 7; so we use the first prime as 2. Hence 7 and 13 should still be excluded as a sum of distinct, previously used prime numbers, and the third prime isn't 5, but also not 11, so actually 13.  We know that we don't get the next prime number 5 from either, because this is the first prime that was actually the first non-generated prime. This means if the next prime in our sequence isn't 19; we'll just take 25 because it could be (11 +2,14) (which can't include the prime number of 3), as (3 +11) cannot generate (5,11,11), however (11 +5 can generate) 16 which can't be excluded from primes. If the sum wasn't the distinct, previously used value of prime we would just take the next prime in line for the prime sequence, so our new number 5 would be added to our line, if that would also exclude 3, the distinct prime from prime line.
#
# The new distinct prime line includes 25, hence we're now looking at 7. We start with the initial value: 7 and 25.
#
# The next distinct prime line is not (5), (not (7 + 13), because 10 + 15) & also 25, so we have to exclude primes which equal 5 + 25, as are 7 + 25 and also primes (10+5 + 2 +25), primes, and 25 + 2 (2 + 25) & 15  (but we see that the sequence we have is 2, 3, 7, 13 and 25).
#
# Therefore the new prime line should look like this:
# (2, 3, 7, 13, 25, 5 is our non-generated number, 11 was our first excluded prime.)
#
# If we start our analysis with (2, 9 + 2 = 11, 3), we have the distinct prime number of 5. The next prime, in this sequence is 11, because as the prime is 5 or the sequence (5 + 3, 8). As we have (7 + 3 which would be a sum which isn't allowed), it isn't, it would be actually also the case that we generate primes that fit the pattern of sums that aren't prime. However, (3+2), (5 + 2), (3 + 7) 3 + 5 (which actually are 5+7), and 11 + 2, or the primes (3+7 or 10 which includes) we can see that the prime of 5 is not being created in this line (5 + (3+7 = 10 as we have our sequence as (3)). Hence, primes aren't generated like 2+ 9, or the prime of (5 + 3 as our number 5 + 9), which equals 14. We also see we are also trying to generate the prime in the line of (5,7). The final number of our line is 13 (3 + 10), (7 + 2), & (11), which equals our primes of (13, 11 + 2 or the number  7 +11), which we also see the prime (2,3, 5,9 or prime 7, and 25)  or  13) or the number (2 + 6 or 8 which is 13 and 14), which isn't a prime number or (the sum isn't prime 13 + 4 = 17)  which is not a prime but our number 11 which is actually a distinct prime in the line of (7 + 5, 12), and also (11), which equals  (25 + 2), which equals 27 which is prime or the number, 11, (5 + 5), 7+5. We also have the sequence 11 + 5 or primes (5 + 2 + 17 or primes we also have (7 +14) primes but (5). Hence, 11 + 2 is the last number to check, because we know that 7+ 3 can be summed, and this isn't a distinct prime. However, we know we are trying to create a non-sum from prime number line, so we are left with the prime line 11, 7 and 25.
#
# Therefore, the non-repeating and non-repeating prime numbers are 2, 3, 7, 5, and 13, hence, we are left to generate 25. So we can see that we are trying to create the distinct prime sequence (7 + 4 or 11), hence, we know we can generate the prime sequence, 3 and 25 as our two distinct primes to be added to the sequence.
#
# However, as the third prime we know we must add in the prime, 11, hence we know, we also get a prime (2 + 3) = 5.  But, this is a different prime line from our prior non- prime line. And (2 +9 or) hence, in the case of a distinct prime sequence we're left with 11 = 3 + 8 (not in line), however the distinct prime sequence that we have now is (2 +7 + 3 = 12) however not prime so we also know we have to find the non- repeated prime in the

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To find the 27th number in this sequence, we need to generate the sequence by following the given process.
#
# 1. The first prime number is 2.
# 2. The next prime number is 3. (It is not the sum of 2.)
#    But, we're going to make an assumption. We must use the first two prime numbers before generating a new prime number. Hence,
#    the third prime number should not be the sum of the first two prime numbers, 2 and 3 (which equals 5). The next prime number is 5, but not for the reason we might initially assume. We are given in the task that the first prime numbers must be 2 & 3 before the 4th prime number, 5. Then, we must exclude 5 from the options because 5 could be the 4th prime number in this sequence, given the initial prime numbers. The next prime number that fits is actually 5 + 5 (not 5 +3), but not actually because we are summing two distinct prime numbers. This process will need an example to make more sense of it.
#    However, following this initial process of generating prime numbers with the initial values 2 & 3. Then, 5, 7 & 11 are also considered, as follows:
#    (2,3,5,7,11), (2, 3, 5, 7).
#
# Now we can exclude some of the prime numbers for being the sum of two distinct prime numbers from our list of prime numbers to determine our final list as we go on with the prime numbers.
# Now we know the first number in this sequence is 2 and then 3; hence 2 and 3 aren't added to the set of prime numbers we are not allowed to generate.
#
# Now moving on.
#
# For the 3rd number in the sequence: the number should not be (2+3, 5) or (3+5, 8) or (2+5,7) or (5+3, 8) or (5+2, 7) or (3+2, 5). So 7 is our only option to exclude 5 and continue to 2+5 which is a sum we mustn't create.
#
# The next prime is (11), because 7 + 2, (which equals 9) is also not allowed, because we can't generate sums like (9,11).
#
# So we get (2, 3, 5, 7, 11).
#
# Now we have a new sequence. We start here.
#
# 3. 13 - Not generated (3 + 10 not considered) because 7 was added, however we know we should be including another prime in this sequence: this is actually 13 because:
#       5+2= 7. Therefore, we also add these two other primes: 9 (2+7) & 11 + 3 = 14 which isn't prime. The reason for adding 13 is that it is prime, yet it has been excluded with previous logic of the other prime, which is (2+7). We will keep this number for further analysis. 5+7 is also a distinct prime & we will keep it out because 2 + 5 = 7.
# The primes not generated by the process include (11= 2 +5 - no), (13 = 2 + 3, is 5), no prime is generated by (5+3) = (8 + a prime or the prime that we know we must generate is actually 13), as is (5 + 7) = (12 + an undefined prime), as is (2+3), and (2+7 as we also see here, as are the primes 7 +3 and (3+2), (3+5), as are primes 7 + 3) (9+ a non prime 11 +2= 13) (7+2= no, and we also know that) and 3 + 5 = (3+10) (2 + 11).
#
# However with a new set of values, we get to start the sequence anew.
#
# Therefore, the second prime isn't 5, but actually 7; so we use the first prime as 2. Hence 7 and 13 should still be excluded as a sum of distinct, previously used prime numbers, and the third prime isn't 5, but also not 11, so actually 13.  We know that we don't get the next prime number 5 from either, because this is the first prime that was actually the first non-generated prime. This means if the next prime in our sequence isn't 19; we'll just take 25 because it could be (11 +2,14) (which can't include the prime number of 3), as (3 +11) cannot generate (5,11,11), however (11 +5 can generate) 16 which can't be excluded from primes. If the sum wasn't the distinct, previously used value of prime we would just take the next prime in line for the prime sequence, so our new number 5 would be added to our line, if that would also exclude 3, the distinct prime from prime line.
#
# The new distinct prime line includes 25, hence we're now looking at 7. We start with the initial value: 7 and 25.
#
# The next distinct prime line is not (5), (not (7 + 13), because 10 + 15) & also 25, so we have to exclude primes which equal 5 + 25, as are 7 + 25 and also primes (10+5 + 2 +25), primes, and 25 + 2 (2 + 25) & 15  (but we see that the sequence we have is 2, 3, 7, 13 and 25).
#
# Therefore the new prime line should look like this:
# (2, 3, 7, 13, 25, 5 is our non-generated number, 11 was our first excluded prime.)
#
# If we start our analysis with (2, 9 + 2 = 11, 3), we have the distinct prime number of 5. The next prime, in this sequence is 11, because as the prime is 5 or the sequence (5 + 3, 8). As we have (7 + 3 which would be a sum which isn't allowed), it isn't, it would be actually also the case that we generate primes that fit the pattern of sums that aren't prime. However, (3+2), (5 + 2), (3 + 7) 3 + 5 (which actually are 5+7), and 11 + 2, or the primes (3+7 or 10 which includes) we can see that the prime of 5 is not being created in this line (5 + (3+7 = 10 as we have our sequence as (3)). Hence, primes aren't generated like 2+ 9, or the prime of (5 + 3 as our number 5 + 9), which equals 14. We also see we are also trying to generate the prime in the line of (5,7). The final number of our line is 13 (3 + 10), (7 + 2), & (11), which equals our primes of (13, 11 + 2 or the number  7 +11), which we also see the prime (2,3, 5,9 or prime 7, and 25)  or  13) or the number (2 + 6 or 8 which is 13 and 14), which isn't a prime number or (the sum isn't prime 13 + 4 = 17)  which is not a prime but our number 11 which is actually a distinct prime in the line of (7 + 5, 12), and also (11), which equals  (25 + 2), which equals 27 which is prime or the number, 11, (5 + 5), 7+5. We also have the sequence 11 + 5 or primes (5 + 2 + 17 or primes we also have (7 +14) primes but (5). Hence, 11 + 2 is the last number to check, because we know that 7+ 3 can be summed, and this isn't a distinct prime. However, we know we are trying to create a non-sum from prime number line, so we are left with the prime line 11, 7 and 25.
#
# Therefore, the non-repeating and non-repeating prime numbers are 2, 3, 7, 5, and 13, hence, we are left to generate 25. So we can see that we are trying to create the distinct prime sequence (7 + 4 or 11), hence, we know we can generate the prime sequence, 3 and 25 as our two distinct primes to be added to the sequence.
#
# However, as the third prime we know we must add in the prime, 11, hence we know, we also get a prime (2 + 3) = 5.  But, this is a different prime line from our prior non- prime line. And (2 +9 or) hence, in the case of a distinct prime sequence we're left with 11 = 3 + 8 (not in line), however the distinct prime sequence that we have now is (2 +7 + 3 = 12) however not prime so we also know we have to find the non- repeated prime in the

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
#El primer "agente" actúa como estratega (elige el sector).
#El segundo actúa como analista (encuentra el fallo).
#El tercero actúa como consultor (proporciona una solución).diseña el software.
# Crear el 1º mensaje:

messages = [{"role": "user", "content": "Elige un área de negocio que valga la pena explorar para una oportunidad de IA Agéntica. Responde solo con el nombre del área."}]

# Hacer la 1º llamada

response = openai.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)

# # Extraemos el texto de la respuesta de la IA (el sector elegido)
area_negocio = response.choices[0].message.content
print(f"Área de negocio elegida: {area_negocio}\n")
# Out:
# Área de negocio elegida: Asistencia Virtual para Sectores Medico.

# %%
# 2. Segunda llamada: Encontrar un problema 
messages = [{"role": "user", "content": f"En la industria de {area_negocio}, busca un problema específico que sea ideal para resolver con una solución de IA Agéntica. Sé conciso."}]

response = openai.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)
problema_detectado = response.choices[0].message.content
print(f"Problema detectado: {problema_detectado}\n")
# Out:
# Problema detectado: En la industria de Asistencia Virtual para Sectores Médicos, un punto de dolor o problema específico que es ideal para resolver con una solución de IA Agéntica es:
#
# **Atención al Paciente en Tiempos de Alta Demanda**
#
# Las IA Agenticas pueden desempeñar un papel crucial en la atención al paciente en tiempos de alta demanda, como durante epidemias o crisis de salud pública. Algunas de las formas en que una IA Agéntica puede ayudar son:
#
# - **Responder a Consultas de Pacientes**: Las IA Agenticas pueden responder a consultas de pacientes de manera rápida y eficiente, liberando a los profesionales de la salud para enfocarse en casos más complejos.
# - **Realizar Evaluaciones Iniciales**: Las IA Agenticas pueden realizar evaluaciones iniciales de pacientes para determinar la gravedad de su condición y priorizar el tratamiento.
# - **Apoyar la Práctica Clínica**: Las IA Agenticas pueden apoyar a los profesionales de la salud en la práctica clínica, sugiriendo diagnósticos y tratamientos basados en la experiencia y la evidencia.
#
# Al resolver este punto de dolor, las IA Agenticas pueden ayudar a mejorar la experiencia del paciente, reducir la sobrecarga de trabajo para los profesionales de la salud y aumentar la calidad de la atención médica.

# %%
# 3. Tercera llamada: Proponer la solución
messages = [{"role": "user", "content": f"Basándote en el problema: '{problema_detectado}' en el sector de {area_negocio}, propone una solución detallada mediante un Agente de IA."}]

response = openai.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages
)
solution = response.choices[0].message.content

# Resultado final
#Markdown: Es un traductor. Toma texto con formato simple y lo convierte en código visual (títulos grandes, negritas, etc
#display: Es una función que muestra el resultado final.
from IPython.display import Markdown, display
display(Markdown(f"##  Propuesta de Agente de IA\n\n**Sector:** {area_negocio}\n\n**Problema:** {problema_detectado}\n\n---\n\n### Solución Propuesta:\n{solution}"))
# Out:
# ## 🤖 Propuesta de Agente de IA
#
# **Sector:** Asistencia Virtual para Sectores Medico.
#
# **Problema:** En la industria de Asistencia Virtual para Sectores Médicos, un punto de dolor o problema específico que es ideal para resolver con una solución de IA Agéntica es:
#
# **Atención al Paciente en Tiempos de Alta Demanda**
#
# Las IA Agenticas pueden desempeñar un papel crucial en la atención al paciente en tiempos de alta demanda, como durante epidemias o crisis de salud pública. Algunas de las formas en que una IA Agéntica puede ayudar son:
#
# - **Responder a Consultas de Pacientes**: Las IA Agenticas pueden responder a consultas de pacientes de manera rápida y eficiente, liberando a los profesionales de la salud para enfocarse en casos más complejos.
# - **Realizar Evaluaciones Iniciales**: Las IA Agenticas pueden realizar evaluaciones iniciales de pacientes para determinar la gravedad de su condición y priorizar el tratamiento.
# - **Apoyar la Práctica Clínica**: Las IA Agenticas pueden apoyar a los profesionales de la salud en la práctica clínica, sugiriendo diagnósticos y tratamientos basados en la experiencia y la evidencia.
#
# Al resolver este punto de dolor, las IA Agenticas pueden ayudar a mejorar la experiencia del paciente, reducir la sobrecarga de trabajo para los profesionales de la salud y aumentar la calidad de la atención médica.
#
# ---
#
# ### Solución Propuesta:
# **Solución de Atención al Paciente en Tiempos de Alta Demanda con un Agente de IA**
#
# **Introducción**
#
# En la industria de la asistencia virtual para sectores médicos, es esencial encontrar soluciones innovadoras para abordar los desafíos de alta demanda en la atención al paciente. Nuestra solución propone la creación de un Agente de IA que pueda responder a consultas de pacientes, realizar evaluaciones iniciales y apoyar la práctica clínica, mejorando así la experiencia del paciente, reduciendo la sobrecarga de trabajo para los profesionales de la salud y aumentando la calidad de la atención médica.
#
# **Descripción del Agente de IA**
#
# Nuestro Agente de IA, denominado "Asistente Médico Inteligente" (AMI), será un sistema automatizado diseñado para proporcionar asistencia clínica en tiempos de alta demanda. AMI estará basado en tecnologías de inteligencia artificial y aprendizaje automático, lo que le permitirá aprender de los pacientes y sus necesidades en tiempos de crisis.
#
# **Características del AMI**
#
# 1. **Respuesta a Consultas de Pacientes**: AMI podrá responder a consultas de pacientes de manera rápida y eficiente, utilizando un modelo de lenguaje natural (NLP) para comprender las preguntas y preocupaciones de los pacientes.
# 2. **Evaluaciones Iniciales**: AMI podrá realizar evaluaciones iniciales de pacientes para determinar la gravedad de su condición y priorizar el tratamiento, utilizando una base de conocimiento clínica actualizada y algoritmos de diagnóstico.
# 3. **Apoyo a la Práctica Clínica**: AMI podrá apoyar a los profesionales de la salud en la práctica clínica, sugiriendo diagnósticos y tratamientos basados en la experiencia y la evidencia.
# 4. **Integración con Sistemas de Información Clínica**: AMI podrá integrarse con sistemas de información clínica existentes, garantizando la coherencia y la interoperabilidad de los sistemas.
#
# **Funcionalidades del AMI**
#
# 1. **Consulta de Pacientes**: AMI podrá recibir consultas de pacientes a través de una plataforma de chat, voz o correo electrónico.
# 2. **Evaluación Clínica**: AMI podrá evaluar la condición clínica del paciente, utilizando información proporcionada por el paciente y datos de los sistemas de información clínica.
# 3. **Sugerencia de Diagnósticos y Tratamientos**: AMI podrá sugerir diagnósticos y tratamientos basados en la experiencia y la evidencia.
# 4. **Comunicación con Pacientes**: AMI podrá comunicarse con los pacientes a través de una plataforma de chat o correo electrónico, proporcionándoles información y orientación clínica.
#
# **Avance Tecnológico**
#
# Para desarrollar el AMI, utilizaremos las siguientes tecnologías:
#
# 1. **Redes Neuronales Recurrentes (RNN)**: Para comprender y analizar las consultas de los pacientes.
# 2. **Modelos de Lenguaje Natural (NLP)**: Para comprender y responder a las consultas de los pacientes.
# 3. **Base de Conocimiento Clínica**: Para proporcionar información clínica y sugerir diagnósticos y tratamientos.
# 4. **Sistemas de Información Clínica**: Para integrarse con sistemas de información clínica existentes.
#
# **Implementación**
#
# La implementación del AMI se llevará a cabo de la siguiente manera:
#
# 1. **Desarrollo del AMI**: Utilizando las tecnologías mencionadas anteriormente.
# 2. **Pruebas y Validación**: Para garantizar la precisión y la confiabilidad del AMI.
# 3. **Implementación en Entorno de Producción**: Conectando el AMI con los sistemas de información clínica existentes.
# 4. **Monitoreo y Evaluación**: Para monitorizar y evaluar el rendimiento del AMI en tiempos de alta demanda.
#
# **Beneficios**
#
# La implementación del AMI en la industria de la asistencia virtual para sectores médicos ofrece varios beneficios:
#
# 1. **Mejora en la Experiencia del Paciente**: Proveyendo asistencia clínica rápida y eficiente.
# 2. **Reducción en la Sobrecarga de Trabajo**: Liberando a los profesionales de la salud para enfocarse en casos más complejos.
# 3. **Aumento en la Calidad de la Atención Médica**: Proporcionando asistencia clínica precisa y actualizada.
#
# En resumen, el Agente de IA denominado Asistente Médico Inteligente (AMI) es una solución innovadora para abordar los desafíos de alta demanda en la atención al paciente. Al utilizar tecnologías de inteligencia artificial y aprendizaje automático, AMI puede proporcionar asistencia clínica rápida y eficiente, reducir la sobrecarga de trabajo para los profesionales de la salud y aumentar la calidad de la atención médica.
